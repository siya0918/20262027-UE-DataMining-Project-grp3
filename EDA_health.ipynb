# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
df_cardiac_recording=pd.read_csv('./data/health/cardiac_recordings.csv')
df_cardiac_signal_samples=pd.read_csv('./data/health/cardiac_signal_samples.csv')
df_clinical_encounters=pd.read_csv('./data/health/clinical_encounters.csv')
df_cardiac_notes=pd.read_csv('./data/health/clinical_notes.csv')
df_clinical_observations=pd.read_csv('./data/health/clinical_observations.csv')
df_patient_administration=pd.read_csv('./data/health/patient_administration.csv')

# %%
def EDA(dataset):
    def info(dataset)
        print(dataset.info())
        print('--')
        print(dataset.describe().T)

# %%
EDA(df_cardiac_recording)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   recording_id              44 non-null     object
#  1   patient_number            44 non-null     object
#  2   encounter_number          44 non-null     object
#  3   recording_date            44 non-null     object
#  4   recording_context         44 non-null     object
#  5   facility_license_number   44 non-null     object
#  6   reviewing_license_number  44 non-null     object
#  7   device_serial_number      44 non-null     object
#  8   device_model              44 non-null     object
#  9   sampling_rate_hz          44 non-null     int64
#  10  sampling_interval_ms      44 non-null     int64
#  11  duration_seconds          44 non-null     float64
#  12  channel_count             44 non-null     int64
#  13  sample_count              44 non-null     int64
# ...

# %%
df_cardiac_recording.describe().T
# Out:
#                       count         mean         std     min      25%  \
# sampling_rate_hz       44.0   112.500000   12.644513   100.0   100.00
# sampling_interval_ms   44.0     9.000000    1.011561     8.0     8.00
# duration_seconds       44.0    19.545455    5.990126    12.0    15.00
# channel_count          44.0     2.000000    0.000000     2.0     2.00
# sample_count           44.0  2202.840909  729.790029  1200.0  1500.00
# device_quality         44.0    91.368182    5.132059    76.9    87.85
#
#                           50%     75%     max
# sampling_rate_hz       112.50   125.0   125.0
# sampling_interval_ms     9.00    10.0    10.0
# duration_seconds        18.00    24.0    30.0
# channel_count            2.00     2.0     2.0
# sample_count          2000.00  3000.0  3750.0
# device_quality          92.55    95.6    98.0

# %%
df_cardiac_recording['patient_number'].unique()
# Out:
# array(['PAT-31162', 'PAT-31040', 'PAT-31115', 'PAT-31233', 'PAT-31065',
#        'PAT-31037', 'PAT-31221', 'PAT-31119', 'PAT-31183', 'PAT-31099',
#        'PAT-31226', 'PAT-31141', 'PAT-31079', 'PAT-31223', 'PAT-31150',
#        'PAT-31095', 'PAT-31131', 'PAT-31014', 'PAT-31016', 'PAT-31166',
#        'PAT-31097', 'PAT-31102', 'PAT-31218', 'PAT-31173', 'PAT-31210',
#        'PAT-31135', 'PAT-31005', 'PAT-31035', 'PAT-31076', 'PAT-31088',
#        'PAT-31231', 'PAT-31107', 'PAT-31063', 'PAT-31057', 'PAT-31020',
#        'PAT-31008', 'PAT-31209', 'PAT-31059', 'PAT-31080', 'PAT-31130',
#        'PAT-31155', 'PAT-31211'], dtype=object)

# %%
df_cardiac_recording.isna().sum()
# Out:
# recording_id                0
# patient_number              0
# encounter_number            0
# recording_date              0
# recording_context           0
# facility_license_number     0
# reviewing_license_number    0
# device_serial_number        0
# device_model                0
# sampling_rate_hz            0
# sampling_interval_ms        0
# duration_seconds            0
# channel_count               0
# sample_count                0
# amplitude_unit              0
# automated_interpretation    0
# recording_notes_code        0
# device_quality              0
# archive_status              0
# dtype: int64

# %%
df_cardiac_recording.isnull().sum()
# Out:
# recording_id                0
# patient_number              0
# encounter_number            0
# recording_date              0
# recording_context           0
# facility_license_number     0
# reviewing_license_number    0
# device_serial_number        0
# device_model                0
# sampling_rate_hz            0
# sampling_interval_ms        0
# duration_seconds            0
# channel_count               0
# sample_count                0
# amplitude_unit              0
# automated_interpretation    0
# recording_notes_code        0
# device_quality              0
# archive_status              0
# dtype: int64

# %%
df_cardiac_recording.duplicated().sum()
# Out:
# 0

# %%
quality_counts = df_cardiac_recording['recording_context'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='deeppink')
plt.title('Count Plot of Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()
